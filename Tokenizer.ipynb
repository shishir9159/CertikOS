# %% [markdown]
# <a href="https://colab.research.google.com/github/shishir9159/CertikOS/blob/master/Tokenizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bangla-ipa

# %%
import re

def process_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()

    processed_lines = []
    for line in lines:
        line = line.strip()
        if not line:
            continue

        if "=" not in line:
            if re.search(r'[^+\=\u0980-\u09FF\s\n]', line):
                continue
            else:
              processed_lines.append(line.replace(" ", ""))
        else:
            parts = line.split("=")
            if len(parts) == 2:
                if "+" in parts[1]:
                  parts[0],parts[1]=parts[1],parts[0]
                processed_lines.append("=".join(parts).strip().replace(" ", ""))
            else:
                print("skipping")
    return "\n".join(processed_lines)

file_path = '/content/raw-dataset.txt'
processed_content = process_file(file_path)
# Out:
# skipping
# skipping

# %%
def write_string_to_file(filename: str, content: str):
    with open(filename, "w", encoding="utf-8") as file:
        file.writelines(line + "\n" for line in content.split("\n"))

def count_lines_in_file(filename: str) -> int:
    with open(filename, 'r', encoding='utf-8') as file:
        return sum(1 for _ in file)

write_string_to_file("output.txt", processed_content)
filename = "output.txt"
line_count = count_lines_in_file(filename)
print(f"Number of lines: {line_count}")
# Out:
# Number of lines: 1985

# %%
from collections import defaultdict

def analyze_file(filename):
    word_counts = defaultdict(int)
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            for line in file:
                line = line.strip()
                if line:
                    parts = line.split("+")
                    if len(parts) == 2:
                        first_word = parts[0]
                        second_word = parts[1].strip().split("=")[0]
                        word_counts[first_word] += 1
                        word_counts[second_word] += 1
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None

    sorted_word_counts = dict(sorted(word_counts.items(), key=lambda item: item[1], reverse=True))
    return sorted_word_counts

filename = "output.txt"
result = analyze_file(filename)

if result:
    for word, count in result.items():
        print(f"{word}: {count}")
# Out:
# নিঃ: 108
# সম্: 90
# উৎ: 87
# এক: 48
# মহা: 46
# ঈশ: 42
# প্রতি: 42
# দুঃ: 42
# অন্ত: 37
# মনঃ: 36
# ইন্দ্র: 35
# অতি: 33
# অন: 29
# ঋত: 26
# পরি: 26
# পুনঃ: 26
# অন্তঃ: 24
# গো: 24
# অক: 24
# কার: 20
# সৎ: 20
# ছেদ: 19
# যথা: 18
# তদ্: 18
# আ: 17
# অনু: 17
# আদি: 17
# ঋষি: 17
# বি: 16
# তৎ: 16
# ঐশ্বর্য: 15
# অন্তর: 15
# চতুঃ: 15
# ষট্: 15
# হিত: 15
# ঈশ্বর: 14
# ঈক্ষা: 14
# পদ: 14
# ত: 14
# উত্তর: 14
# জগৎ: 14
# ইচ্ছা: 14
# প্র: 14
# কর: 14
# পিতৃ: 14
# সু: 13
# দিক্: 13
# পর: 13
# য: 13
# এব: 12
# অভি: 12
# অহঃ: 12
# জন: 12
# ঊর্ধ্ব: 12
# উক: 12
# বাক্: 12
# যোগ: 12
# দশ: 11
# তি: 11
# আলয়: 11
# বন: 11
# উৎসব: 11
# ময়: 11
# পতি: 11
# এ: 11
# বহিঃ: 11
# অক্ষ: 10
# অধিক: 10
# অধম: 10
# ঋণ: 10
# আদেশ: 10
# আগত: 10
# আশা: 10
# ইতি: 10
# ঊর্মি: 10
# নর: 10
# পো: 10
# বিপদ: 10
# সম: 10
# স্ব: 10
# শিরঃ: 10
# উদ্: 9
# উক্তি: 9
# কথা: 9
# কিম্: 9
# কৃত: 9
# জল: 9
# ঈ: 9
# ছবি: 9
# বার: 9
# ইত: 8
# অবধি: 8
# অধি: 8
# ইষ্ট: 8
# ভব: 8
# গঙ্গা: 8
# এষণা: 8
# বিদ্যা: 8
# দেব: 8
# ওষধি: 8
# ...

# %%
def sort_files_by_first_char(input_file, output_file):
    try:
        with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', encoding='utf-8') as outfile:
            lines = infile.readlines()
            lines.sort(key=lambda line: line[0] if line else "")
            outfile.writelines(lines)
    except FileNotFoundError:
        print(f"Error: Input file '{input_file}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

input_filename = "output.txt"
output_filename = "sorted_output.txt"
sort_files_by_first_char(input_filename, output_filename)

# %%
def remove_duplicate_lines(input_file, output_file):
    """Removes duplicate lines from a file and writes the unique lines to a new file."""
    try:
        with open(input_file, 'r', encoding='utf-8') as infile, open(output_file, 'w', encoding='utf-8') as outfile:
            lines_seen = set()  # Use a set to store unique lines
            for line in infile:
                if line not in lines_seen:
                    outfile.write(line)
                    lines_seen.add(line)
    except FileNotFoundError:
        print(f"Error: Input file '{input_file}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

def count_lines_in_file(filename: str) -> int:
    with open(filename, 'r', encoding='utf-8') as file:
        return sum(1 for _ in file)

input_filename = "sorted_output.txt"
output_filename = "unique_sorted_output.txt"
remove_duplicate_lines(input_filename, output_filename)
count = count_lines_in_file("unique_sorted_output.txt")
print(count)
# Out:
# 1359

# %%
# !pip install torchtext certifi==2024.12.14 charset-normalizer==3.4.1 colorama==0.4.6 docutils==0.21.2 filelock==3.17.0 fsspec==2024.12.0 id==1.5.0 idna==3.10 jaraco.classes==3.4.0 jaraco.context==6.0.1 jaraco.functools==4.1.0 Jinja2==3.1.5 keyring==25.6.0 markdown-it-py==3.0.0 MarkupSafe==3.0.2 mdurl==0.1.2 more-itertools==10.6.0 mpmath==1.3.0 networkx==3.4.2 nh3==0.2.20 numpy==2.2.2 packaging==24.2 pandas==2.2.3 Pygments==2.19.1 python-dateutil==2.9.0.post0 pytz==2024.2 pywin32-ctypes==0.2.3 readme_renderer==44.0 requests==2.32.3 requests-toolbelt==1.0.0 rfc3986==2.0.0 rich==13.9.4 sentencepiece==0.2.0 setuptools==75.8.0 six==1.17.0 sympy==1.13.3 torch==2.4.1 torchdata==0.7.1 torchtext==0.6.0 tqdm==4.67.1 twine==6.1.0 typing_extensions==4.12.2 tzdata==2025.1 urllib3==2.3.0 wheel==0.45.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.4/744.4 kB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 90.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 115.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 22.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 34.7 MB/s eta 0:00:00
# ...

# %%
import pathlib
import pandas as pd
import torch
import warnings
import random
from torch import nn
from torchtext import data as data
from torchtext.data import Field

# Suppress all warnings
warnings.filterwarnings("ignore")

# Suppress only UserWarnings
warnings.filterwarnings("ignore", category=UserWarning)

ipa_vocab = "data/ipa_vocab_data.csv"
path = "model/ipa_model.pth"

if torch.cuda.is_available():
    dev = "cuda:0"
    print("GPU is available.")
else:
    dev = "cpu"
device = torch.device(dev)

SEED = 32

# IPA dataset reading
df = pd.read_csv(ipa_vocab, delimiter="\t", names=["ban", "ipa"])


# Section 2: Tokenization and Data Processing

def myTokenizerBAN(x):
    x = ' '.join(x)
    x = x.split(' ')
    return list(x)


def myTokenizerIPA(x):
    x = ' '.join(x)
    x = x.split(' ')
    return list(x)


SRC = Field(tokenize=myTokenizerBAN, batch_first=False, init_token="<sos>", eos_token="<eos>")
TARGET = Field(tokenize=myTokenizerIPA, batch_first=False, tokenizer_language="ipa", init_token="<sos>",
               eos_token="<eos>")


class DataFrameDataset(data.Dataset):
    """
        This code belongs to

        Preface:
        - to point out one thing about the transformer what it could do is to enable
            training on the whole sequence at once but on really using it for translation it predicts the next word
            then it feeds the prediction into the sequence again until the model predict <eos> token (with a max length ofc)
        - I'm using adagrad because it assigns bigger updates to less frequently updated weights. so thought it could be useful for words not used a lot
        - ?????????? - HOPE VAI WILL ADD MORE.
        - ????????? - HOPE VAI WILL ADD MORE.
        - ???????? - HOPE VAI WILL ADD MORE.

        Returns:
        - translation to ipa from bangla words
    """

    def __init__(self, df, src_field, target_field, is_test=False, **kwargs):
        fields = [('ban', src_field), ('ipa', target_field)]
        examples = []
        for i, row in df.iterrows():
            ban = row.ban
            ipa = row.ipa
            examples.append(data.Example.fromlist([ban, ipa], fields))

        super().__init__(examples, fields, **kwargs)


torchdataset = DataFrameDataset(df, SRC, TARGET)

train_data, valid_data = torchdataset.split(split_ratio=0.8, random_state=random.seed(SEED))

SRC.build_vocab(train_data, min_freq=2)
TARGET.build_vocab(train_data, min_freq=2)

BATCH_SIZE = 64

train_iterator, valid_iterator = data.BucketIterator.splits(
    (train_data, valid_data),
    batch_size=BATCH_SIZE,
    device=device,
    sort=False,
    sort_within_batch=False,
    shuffle=True)


# section 3
class TranslateTransformer(nn.Module):
    def __init__(
            self,
            embedding_size,
            src_vocab_size,
            trg_vocab_size,
            src_pad_idx,
            num_heads,
            num_encoder_layers,
            num_decoder_layers,
            max_len,
    ):
        super(TranslateTransformer, self).__init__()
        self.srcEmbeddings = nn.Embedding(src_vocab_size, embedding_size)
        self.trgEmbeddings = nn.Embedding(trg_vocab_size, embedding_size)
        self.srcPositionalEmbeddings = nn.Embedding(max_len, embedding_size)
        self.trgPositionalEmbeddings = nn.Embedding(max_len, embedding_size)
        self.transformer = nn.Transformer(
            embedding_size,
            num_heads,
            num_encoder_layers,
            num_decoder_layers,
        )
        self.fc_out = nn.Linear(embedding_size, trg_vocab_size)
        self.dropout = nn.Dropout(0.1)
        self.src_pad_idx = src_pad_idx
        self.max_len = max_len

    def make_src_mask(self, src):
        src_mask = src.transpose(0, 1) == self.src_pad_idx

        return src_mask.to(device)

    def forward(self, x, trg):
        src_seq_length = x.shape[0]
        N = x.shape[1]
        trg_seq_length = trg.shape[0]
        # adding zeros is an easy way
        src_positions = (
                torch.arange(0, src_seq_length)
                .reshape(src_seq_length, 1) + torch.zeros(src_seq_length, N)
        ).to(device)

        trg_positions = (
                torch.arange(0, trg_seq_length)
                .reshape(trg_seq_length, 1) + torch.zeros(trg_seq_length, N)
        ).to(device)

        srcWords = self.dropout(self.srcEmbeddings(x.long()) + self.srcPositionalEmbeddings(src_positions.long()))
        trgWords = self.dropout(self.trgEmbeddings(trg.long()) + self.trgPositionalEmbeddings(trg_positions.long()))

        src_padding_mask = self.make_src_mask(x)
        trg_mask = self.transformer.generate_square_subsequent_mask(trg_seq_length).to(device)

        out = self.transformer(srcWords, trgWords, src_key_padding_mask=src_padding_mask, tgt_mask=trg_mask)
        out = self.fc_out(out)
        return out


# section 4
# No. of unique tokens in text
src_vocab_size = len(SRC.vocab)
# print("Size of Bangla vocabulary:", src_vocab_size)

# No. of unique tokens in label
trg_vocab_size = len(TARGET.vocab)
# print("Size of IPA vocabulary:", trg_vocab_size)

num_heads = 8
num_encoder_layers = 2
num_decoder_layers = 2

max_len = 100
embedding_size = 256
src_pad_idx = SRC.vocab.stoi["<pad>"]


class BanglaIPATranslator:

    def __init__(self):
        self.model = self.load_model(path)

    def load_model(self, model_path):
        model = TranslateTransformer(
            embedding_size,
            len(SRC.vocab),
            len(TARGET.vocab),
            SRC.vocab.stoi["<pad>"],
            num_heads,
            num_encoder_layers,
            num_decoder_layers,
            max_len
        ).to(device)
        model.load_state_dict(torch.load(model_path, map_location=device))
        return model

    def translate(self, sentence):
        self.model.eval()
        processed_sentence = SRC.process([myTokenizerBAN(sentence)]).to(device)
        trg = ["<sos>"]
        for _ in range(60):
            trg_indices = [TARGET.vocab.stoi[word] for word in trg]
            outputs = torch.Tensor(trg_indices).unsqueeze(1).to(device)
            outputs = self.model(processed_sentence, outputs)

            predicted_word = TARGET.vocab.itos[outputs.argmax(2)[-1:].item()]
            if predicted_word == "<unk>":
                continue
            trg.append(predicted_word)
            if predicted_word == "<eos>":
                break
        return "".join([word for word in trg if word != "<unk>"][1:-1])
# Out:
# GPU is available.

# %%
import re
from collections import defaultdict

def process_and_convert(filename):
    try:
        with open(filename, 'r', encoding='utf-8') as infile, open("ipa_output.txt", 'w', encoding='utf-8') as outfile:
            ipa = BanglaIPATranslator()
            for line in infile:
                line = line.strip()
                if line:
                    parts = line.split("=")
                    if len(parts) == 2:
                        bangla_combined_word = parts[1]
                        ipa_combined_word = ipa.translate(bangla_combined_word)
                        print(ipa_combined_word)
                        part = parts[0].split("+")
                        if len(part) != 2:
                            continue
                        part1, part2 = ipa.translate(part[0]), ipa.translate(part[1])

                        outfile.write(f"{part1}+{part2}={ipa_combined_word}\n")

    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")

process_and_convert("unique_sorted_output.txt")
# Out:
# ɔkkʰou̯hini
# ɔkʰileʃ
# ɔgnut̪pat̪
# ɔŋgoccʰed̪
# ɔɟɔnt̪o
# ɔt̪oeb
# ot̪it̪
# ot̪ind̪riɟɔ
# ot̪ibo
# ot̪t̪od̪ʰik
# ot̪t̪ont̪o
# ot̪t̪acar
# ot̪t̪aʃcorɟo
# ot̪t̪oi̯ʃʃorɟo
# ɔd̪d̪abod̪ʰi
# ɔd̪ʰomɔrno
# od̪ʰiʃʃɔr
# od̪d̪ʰoɟɔn
# od̪d̪ʰad̪eʃ
# od̪d̪ʰuʃit̪o
# onuccʰed̪
# onumɔt̪anuʃare
# ɔnurd̪ʰo
# ɔnt̪obort̪i
# ɔnt̪obʰukt̪o
# ɔnnoɟɔ
# ɔnnit̪o
# ɔnneʃɔn
# ɔporanno
# ɔpekkʰa
# ɔboccʰed̪
# ɔbind̪ʰon
# ɔbekkʰon
# ɔbɟo
# obʰikkʰa
# obʰiʃto
# ɔbbʰægɔt̪o
# ɔbbʰut̪t̪ʰan
# ɔbbʰud̪ɟɔŋ
# ɔloŋkar
# ɔhorɔho
# ɔhɔrniʃ
# ot̪t̪ukt̪i
# onnanno
# ad̪ʰobʰag
# ot̪ind̪ro
# ot̪ind̪roʲ
# ot̪iʃ
# ot̪t̪od̪bʰut̪
# ot̪t̪unnot̪i
# ot̪ind̪roʲ
# ɔd̪riʃ
# ɔd̪ʰopɔt̪on
# ɔd̪ʰogɔmon
# ɔd̪ʰogami
# ɔd̪ʰobʰag
# ɔd̪ʰomukʰ
# ɔd̪ʰorekʰ
# od̪d̪ʰoʲon
# ot̪ind̪roʲ
# ɔnt̪okon
# ɔnt̪okkriɽa
# ɔnt̪opur
# ɔnt̪oʃʃot̪ru
# ɔnt̪oʃʃil
# ɔnt̪oʃɔŋgot̪i
# ɔnt̪oʃɔlila
# ɔnt̪oralok
# ɔnt̪ɔrɟɔgɔt̪
# ɔnt̪ɔrɟɔl
# ɔnt̪ɔrgæn
# ɔnt̪ornihit̪o
# ɔnt̪orbɔrt̪i
# ɔnt̪orbʰed̪i
# ɔnt̪ɔrmad̪ʰurɟo
# ɔnt̪orɟami
# ɔnt̪orlin
# ɔporapɔr
# ɔbbʰud̪ɔʲ
# ɔʲomɔʲ
# ...

# %%
from collections import defaultdict

def analyze_plus_combinations(filename):
    plus_combinations = defaultdict(int)
    try:
        with open(filename, 'r', encoding='utf-8') as file:
            for line in file:
                line = line.strip()
                if line and "+" in line:
                    parts = line.split("+")
                    if len(parts) >= 2:
                        for i in range(len(parts) - 1):
                            combination = parts[i] + "+" + parts[i+1]
                            plus_combinations[combination] += 1
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None

    return dict(plus_combinations)

filename = "ipa_output.txt"
result = analyze_plus_combinations(filename)

if result:
    for combination, count in result.items():
        print(f"{combination}: {count}")
# Out:
# ɔkkʰo+uhini=ɔkkʰou̯hini: 2
# ɔkʰil+iʃ=ɔkʰileʃ: 1
# ɔgni+ut̪pat̪=ɔgnut̪pat̪: 1
# ɔŋgo+cʰed̪=ɔŋgoccʰed̪: 1
# ɔc+ɔnt̪o=ɔɟɔnt̪o: 3
# ɔt̪o+eb=ɔt̪oeb: 2
# ot̪i+it̪o=ot̪it̪: 1
# ot̪i+ind̪riɟɔ=ot̪ind̪riɟɔ: 1
# ot̪i+ib=ot̪ibo: 1
# ot̪i+od̪ʰik=ot̪t̪od̪ʰik: 1
# ot̪i+ɔnt̪o=ot̪t̪ont̪o: 1
# ot̪i+acar=ot̪t̪acar: 1
# ot̪i+aʃcorɟo=ot̪t̪aʃcorɟo: 1
# ot̪i+oi̯ʃʃorɟo=ot̪t̪oi̯ʃʃorɟo: 1
# ɔd̪d̪o+ɔbod̪ʰi=ɔd̪d̪abod̪ʰi: 1
# ɔd̪ʰɔm+rin=ɔd̪ʰomɔrno: 1
# od̪ʰi+iʃʃɔr=od̪ʰiʃʃɔr: 1
# od̪ʰi+ɔɟoi̯no=od̪d̪ʰoɟɔn: 1
# od̪ʰi+ad̪eʃ=od̪d̪ʰad̪eʃ: 1
# od̪ʰi+uʃit̪o=od̪d̪ʰuʃit̪o: 1
# onu+cʰed̪=onuccʰed̪: 1
# onumot̪i+onuʃare=onumɔt̪anuʃare: 1
# onu+urd̪ʰo=ɔnurd̪ʰo: 1
# ɔnt̪o+bort̪i=ɔnt̪obort̪i: 1
# ɔnt̪o+bʰukt̪o=ɔnt̪obʰukt̪o: 1
# onu+ɔɟoi̯=ɔnnoɟɔ: 1
# onu+it̪o=ɔnnit̪o: 1
# onu+eʃon=ɔnneʃɔn: 1
# ɔpor+ɔhno=ɔporanno: 1
# ɔp+ikkʰa=ɔpekkʰa: 1
# ɔb+cʰed̪=ɔboccʰed̪: 1
# ɔp+ind̪ʰon=ɔbind̪ʰon: 1
# ɔb+ikkʰon=ɔbekkʰon: 1
# ɔp+ɟ=ɔbɟo: 1
# obʰi+ikkʰa=obʰikkʰa: 1
# obʰi+iʃto=obʰiʃto: 1
# obʰi+agɔt̪o=ɔbbʰægɔt̪o: 1
# ...
